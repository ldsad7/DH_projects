# %%
import urllib.request
import re
import json
import matplotlib.pyplot as plt
import math
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error as MSE
from datetime import date
import copy
import os
import operator
# %matplotlib inline

# %%
all_ = dict()
for key in 'reposts, subscriptions, friends, first_name, last_name, graduation, faculty_titles, faculty_ids, university_titles, university_ids, city, country, verified, sex, bdate, home_town, has_photo, photo_max_orig, domain, has_mobile, contacts, age, site, universities, schools, status, last_seen, followers_count, occupation, nickname, relatives, relation, personal, wall_comments, activities, interests, music, movies, tv, books, games, about, quotes, career, military'.split(', '):
    all_[key] = []

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'PutinTeam.json'), 'r', encoding='utf8') as f:
    all_ = json.load(f)

# %%
for key in all_:
    print(key, ':', len(all_[key]))
# Out:
# reposts : 24497
# subscriptions : 24497
# friends : 24497
# first_name : 24497
# last_name : 24497
# graduation : 24497
# faculty_titles : 24497
# faculty_ids : 24497
# university_titles : 24497
# university_ids : 24497
# city : 24497
# country : 24497
# verified : 24497
# sex : 24497
# bdate : 24497
# home_town : 24497
# has_photo : 24497
# photo_max_orig : 24497
# domain : 24497
# has_mobile : 24497
# contacts : 24497
# age : 24497
# site : 24497
# universities : 24497
# schools : 24497
# status : 24497
# last_seen : 24497
# followers_count : 24497
# occupation : 24497
# nickname : 24497
# relatives : 24497
# relation : 24497
# personal : 24497
# wall_comments : 24497
# activities : 24497
# interests : 24497
# music : 24497
# movies : 24497
# tv : 24497
# books : 24497
# games : 24497
# about : 24497
# quotes : 24497
# career : 24497
# military : 24497

# %%
domains = set()
indices = []

# %%
for i, elem in enumerate(all_['domain']):
    if elem not in domains:
        domains.add(elem)
    else:
        indices.append(i)

# %%
new = pd.DataFrame(all_)

# %%
# Out:
#                                                    about  \
# 0                                  Все свое несу в себе.
# 11                                            Живая (с.)
# 66     Все хорошо. Живу в Питере. Рядом двое самых лю...
# 85                                  Со стороны виднее...
# 89                 интересно - что здесь можно написать?
# 102    Желтое солнечное семя.\nЯ пульсирую, чтобы нац...
# 125    Мой профайл - https://vimeo.com/75724940\n\nОр...
# 136    Пахнут осенью рыжие волосы, \nАроматов моих на...
# 177    О себе мне сказать нечего, я такой же, как все...
# 178                                 Как же меня все  ...
# 181       высокий мускулистый блондин с голубыми глазами
# 184    Подвеска колоколов, настройка звонниц из колок...
# 195    исповедую гуманизм и пацифизм. \nверю в чудеса...
# 214                                       чуть хуже всех
# 222    Вступайте в мою группу :: http://vk.com/dimo_p...
# ...

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'about_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['about']):
        f.write(about.strip() + '\n____________________________\n')

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'about_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(popular_words, f, ensure_ascii=True)

# %%
popular_words = dict()
for about in pd.unique(new['about']):
    words = about.lower().split()
    for word in words:
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 1938),
#  ('и', 1307),
#  ('в', 964),
#  ('не', 691),
#  ('я', 645),
#  ('на', 387),
#  ('с', 315),
#  ('что', 256),
#  ('по', 204),
#  ('люблю', 178),
#  ('как', 163),
#  ('но', 162),
#  ('мне', 147),
#  ('это', 141),
#  ('меня', 140),
#  ('все', 134),
#  ('а', 131),
#  ('к', 117),
#  ('у', 103),
#  ('то', 102),
#  ('человек', 102),
#  ('за', 101),
#  ('от', 101),
#  ('для', 99),
#  ('так', 86),
#  ('жизни', 85),
#  ('из', 83),
#  ('очень', 82),
#  ('раз', 81),
#  ('всегда', 79),
#  ('о', 79),
#  ('года', 74),
#  ('есть', 73),
#  ('вы', 72),
#  ('только', 72),
#  ('он', 70),
#  ('если', 70),
#  ('ты', 68),
#  ('или', 67),
#  ('просто', 63),
#  ('жизнь', 62),
#  ('когда', 60),
#  ('кто', 58),
#  ('всё', 54),
#  ('его', 53),
#  ('себе', 51),
#  ('мы', 50),
#  ('же', 50),
#  ('быть', 50),
#  ('нет', 47),
#  ('людей', 47),
#  (':', 47),
#  ('the', 44),
#  ('and', 43),
#  ('ни', 43),
#  ('себя', 42),
#  ('место', 42),
#  ('их', 41),
#  ('будет', 41),
#  ('до', 41),
# ...

# %%
all_['is_about'] = []

# %%
for elem in all_['about']:
    if elem.strip() != '':
        all_['is_about'].append(1)
    else:
        all_['is_about'].append(0)

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'quotes_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['quotes']):
        f.write(about.strip() + '\n____________________________\n')

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'quotes_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(popular_words, f, ensure_ascii=True)

# %%
popular_words = dict()
for about in pd.unique(new['quotes']):
    words = about.lower().split()
    for word in words:
        word = word.strip('.,/><?!@#$%^&*();\"\'«»—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 3453),
#  ('не', 2934),
#  ('и', 2426),
#  ('в', 1718),
#  ('что', 1226),
#  ('на', 833),
#  ('а', 742),
#  ('я', 739),
#  ('это', 728),
#  ('с', 720),
#  ('ты', 609),
#  ('если', 526),
#  ('то', 487),
#  ('как', 486),
#  ('кто', 458),
#  ('все', 446),
#  ('но', 441),
#  ('мы', 384),
#  ('когда', 361),
#  ('у', 349),
#  ('к', 344),
#  ('он', 329),
#  ('от', 326),
#  ('за', 316),
#  ('вы', 314),
#  ('чтобы', 304),
#  ('жизнь', 301),
#  ('так', 299),
#  ('есть', 291),
#  ('только', 290),
#  ('быть', 274),
#  ('о', 263),
#  ('его', 246),
#  ('из', 235),
#  ('чем', 233),
#  ('для', 232),
#  ('тебя', 228),
#  ('нет', 225),
#  ('по', 218),
#  ('всегда', 216),
#  ('человек', 206),
#  ('нас', 203),
#  ('мне', 200),
#  ('жизни', 200),
#  ('они', 193),
#  ('себя', 191),
#  ('никогда', 191),
#  ('всё', 186),
#  ('тот', 185),
#  ('будет', 184),
#  ('ни', 181),
#  ('меня', 179),
#  ('может', 175),
#  ('бы', 173),
#  ('люди', 170),
#  ('того', 170),
#  ('тебе', 164),
#  ('их', 163),
# ...

# %%
all_['is_quotes'] = []

# %%
for elem in all_['quotes']:
    if elem.strip() != '':
        all_['is_quotes'].append(1)
    else:
        all_['is_quotes'].append(0)

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'games_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['games']):
        f.write(about.strip() + '\n____________________________\n')

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'games,_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(popular_words, f, ensure_ascii=True)

# %%
popular_words = dict()
for about in pd.unique(new['games']):
    words = about.lower().split()
    for word in words:
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 546),
#  ('и', 161),
#  ('of', 117),
#  ('the', 90),
#  ('в', 90),
#  ('футбол', 72),
#  ('не', 65),
#  ('gta', 59),
#  ('игры', 51),
#  ('на', 48),
#  ('шахматы', 48),
#  ('с', 45),
#  (':', 40),
#  ('world', 38),
#  ('хоккей', 37),
#  ('fifa', 32),
#  ('war', 31),
#  ('for', 31),
#  ('что', 31),
#  ('волейбол', 30),
#  ('жизнь', 30),
#  ('call', 29),
#  ('все', 28),
#  ('мафия', 28),
#  ('нарды', 28),
#  ('nfs', 26),
#  ('need', 26),
#  ('теннис', 26),
#  ('играю', 23),
#  ('dead', 23),
#  ('warcraft', 23),
#  ('покер', 23),
#  ('бильярд', 22),
#  ('баскетбол', 22),
#  ('cs', 19),
#  ('настольный', 18),
#  ('то', 17),
#  ('duty', 17),
#  ('s.t.a.l.k.e.r', 17),
#  ('theft', 16),
#  ('grand', 16),
#  ('dota', 16),
#  ('battlefield', 16),
#  ('игра', 16),
#  ('max', 16),
#  ('starcraft', 16),
#  ('sims', 15),
#  ('а', 15),
#  ('speed', 15),
#  ('creed', 15),
#  ('шашки', 15),
#  ('прятки', 15),
#  ('and', 14),
#  ('я', 14),
#  ('ролевые', 14),
#  ('fallout', 14),
# ...

# %%
popular_words = dict()
for book in pd.unique(new['games']):
    books = book.lower().split(',')
    for word in books:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 67),
#  ('футбол', 54),
#  ('шахматы', 36),
#  ('волейбол', 28),
#  ('хоккей', 25),
#  ('нарды', 23),
#  ('мафия', 21),
#  ('gta', 20),
#  ('баскетбол', 19),
#  ('fifa', 18),
#  ('бильярд', 16),
#  ('покер', 16),
#  ('настольный теннис', 14),
#  ('шашки', 13),
#  ('nfs', 12),
#  ('s.t.a.l.k.e.r', 11),
#  ('world of tanks', 11),
#  ('боулинг', 10),
#  ('прятки', 10),
#  ('dota ', 9),
#  ('карты', 9),
#  ('гонки', 9),
#  ('battlefield ', 9),
#  ('stalker', 9),
#  ('world of warcraft', 9),
#  ('gta ', 9),
#  ('жизнь', 9),
#  ('cs', 8),
#  ('wot', 8),
#  ('бадминтон', 8),
#  ('монополия', 8),
#  ('call of duty', 7),
#  ('ролевые', 7),
#  ('skyrim', 7),
#  ('overwatch', 6),
#  ('the sims ', 6),
#  ('minecraft', 6),
#  ('``````````````````````|``````|`````````|', 6),
#  ('сталкер', 6),
#  ('стратегии', 6),
#  ('mafia ', 6),
#  ('cs:go', 5),
#  ('warface', 5),
#  ('pes', 5),
#  ('warcraft', 5),
#  ('фифа', 5),
#  ('бутылочка', 5),
#  ('nhl', 5),
#  ('стрелялки', 5),
#  ('домино', 5),
# ...

# %%
all_['is_games'] = []

# %%
for elem in all_['games']:
    if elem.strip() != '':
        all_['is_games'].append(1)
    else:
        all_['is_games'].append(0)

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'books_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['books']):
        f.write(about.strip() + '\n____________________________\n')

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'books,_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(popular_words, f, ensure_ascii=True)

# %%
popular_words = dict()
for about in pd.unique(new['books']):
    words = about.lower().split()
    for word in words:
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 671),
#  ('и', 590),
#  ('в', 208),
#  ('с', 87),
#  ('не', 87),
#  ('книги', 86),
#  ('мастер', 83),
#  ('маргарита', 82),
#  ('а', 81),
#  ('на', 78),
#  ('учебник', 77),
#  ('по', 73),
#  ('о', 72),
#  ('все', 66),
#  ('булгаков', 53),
#  ('из', 52),
#  ('как', 47),
#  ('достоевский', 46),
#  ('мир', 44),
#  ('для', 41),
#  ('много', 40),
#  ('война', 39),
#  ('пушкин', 39),
#  ('м', 35),
#  ('к', 34),
#  ('толстой', 33),
#  ('литература', 33),
#  ('фантастика', 32),
#  ('александр', 31),
#  ('ремарк', 31),
#  ('от', 31),
#  ('ха', 29),
#  ('коэльо', 29),
#  ('я', 29),
#  ('жизни', 28),
#  ('библия', 28),
#  ('история', 28),
#  ('the', 27),
#  ('детективы', 27),
#  ('гарри', 27),
#  ('михаил', 26),
#  ('стивен', 26),
#  ('читать', 26),
#  ('люблю', 26),
#  ('гоголь', 25),
#  ('приключения', 25),
#  ('мария', 25),
#  ('исторические', 25),
#  ('что', 25),
#  ('произведения', 25),
#  ('преступление', 24),
#  ('три', 24),
#  ('р', 24),
#  ('дон', 24),
#  ('классика', 24),
# ...

# %%
popular_words = dict()
for book in pd.unique(new['books']):
    books = book.lower().split(',')
    for word in books:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 130),
#  ('мастер и маргарита', 34),
#  ('библия', 20),
#  ('война и мир', 18),
#  ('булгаков', 17),
#  ('достоевский', 14),
#  ('фантастика', 13),
#  ('детективы', 12),
#  ('гарри поттер', 12),
#  ('тихий дон', 12),
#  ('пушкин', 12),
#  ('стивен кинг', 12),
#  ('преступление и наказание', 11),
#  ('чехов', 11),
#  ('алхимик', 10),
#  ('исторические', 9),
#  ('психология', 8),
#  ('пауло коэльо', 8),
#  ('гоголь', 8),
#  ('герой нашего времени', 7),
#  ('романы', 7),
#  ('белый клык', 7),
#  ('граф монте-кристо', 7),
#  ('есенин', 7),
#  ('много', 6),
#  ('история', 6),
#  ('классика', 6),
#  ('маленький принц', 6),
#  ('дейл карнеги', 6),
#  ('булгаков "мастер и маргарита', 6),
#  ('букварь', 6),
#  ('толстой', 6),
#  ('собачье сердце', 6),
#  ('русская классика', 6),
#  ('властелин колец', 6),
#  ('мёртвые души', 5),
#  ('братья карамазовы', 5),
#  ('анна каренина', 5),
#  ('сумерки', 5),
#  ('робинзон крузо', 5),
#  ('омар хайям', 5),
#  ('роберт кийосаки', 5),
# ...

# %%
all_['is_books'] = []

# %%
for elem in all_['books']:
    if elem.strip() != '':
        all_['is_books'].append(1)
    else:
        all_['is_books'].append(0)

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'career', 'military', 'is_about', 'is_quotes', 'is_games', 'is_books'])

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'tv_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['tv']):
        f.write(about.strip() + '\n____________________________\n')

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'tv,_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(popular_words, f, ensure_ascii=True)

# %%
popular_words = dict()
for about in pd.unique(new['tv']):
    words = about.lower().split(',')
    for word in words:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 98),
#  ('квн', 42),
#  ('comedy club', 27),
#  ('голос', 23),
#  ('камеди клаб', 20),
#  ('новости', 19),
#  ('пусть говорят', 18),
#  ('уральские пельмени', 12),
#  ('вечерний ургант', 12),
#  ('прожекторперисхилтон', 12),
#  ('дом', 10),
#  ('что? где? когда', 9),
#  ('универ', 9),
#  ('импровизация', 9),
#  ('наша раша', 9),
#  ('битва экстрасенсов', 9),
#  ('нет', 9),
#  ('друзья', 8),
#  ('top gear', 8),
#  ('камеди', 8),
#  ('своя игра', 7),
#  (' минут', 7),
#  ('галилео', 7),
#  ('большая разница', 7),
#  ('не смотрю', 7),
#  ('интерны', 7),
#  ('орел и решка', 6),
#  (' кадров', 6),
#  ('большие гонки', 6),
#  ('жизнь', 6),
#  ('поединок', 6),
#  ('вести', 6),
#  ('голос дети', 5),
#  ('прямой эфир', 5),
#  ('один в один', 5),
#  ('гриффины', 5),
#  ('спорт', 5),
#  ('давай поженимся', 5),
#  ('танцы', 5),
#  ('comedy woman', 5),
#  ('stand up', 5),
#  ('поле чудес', 5),
#  ('кухня', 5),
#  ('лучше всех', 5),
#  ('что?где?когда', 5),
#  ('время', 5),
# ...

# %%
all_['is_tv'] = []

# %%
for elem in all_['tv']:
    elem = str(elem)
    if elem.strip() != '':
        all_['tv'].append(1)
    else:
        all_['tv'].append(0)

# %%
all_['tv']
# Out:
# ['нет',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'камеди))))))))))))))))))))',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'А телешоу можно любить?!',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Academia, Физика нереального, Монти Пайтон, Майти Буш, Доктор Кто, Вечер с Владимиром Соловьёвым',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Не смотрю ерунду',
# ...
