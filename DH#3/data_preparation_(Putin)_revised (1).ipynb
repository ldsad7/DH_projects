# %%
import urllib.request
import re
import json
import matplotlib.pyplot as plt
import math
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error as MSE
from datetime import date
import copy
import os
import operator
# %matplotlib inline

# %%
all_ = dict()
for key in 'reposts, subscriptions, friends, first_name, last_name, graduation, faculty_titles, faculty_ids, university_titles, university_ids, city, country, verified, sex, bdate, home_town, has_photo, photo_max_orig, domain, has_mobile, contacts, age, site, universities, schools, status, last_seen, followers_count, occupation, nickname, relatives, relation, personal, wall_comments, activities, interests, music, movies, tv, books, games, about, quotes, career, military'.split(', '):
    all_[key] = []

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'PutinTeam.json'), 'r', encoding='utf8') as f:
    all_ = json.load(f)

# %%
new = pd.DataFrame(all_)

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'movies_Putin.txt'), 'w', encoding='utf8') as f:
    for about in pd.unique(new['movies']):
        f.write(about.strip() + '\n____________________________\n')

# %%
popular_words = dict()
for about in new['subscriptions']:
    words = about.lower().split()
    for word in words:
        word = word.strip()
        word = word.strip(' ')
        word = word.strip('.,/><?!@#$%^&*()«»;\\"\'`|—–_-+[]=')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-21c8719fbf82> in <module>()
#       1 popular_words = dict()
#       2 for about in new['subscriptions']:
# ----> 3     words = about.lower().split()
#       4     for word in words:
#       5         word = word.strip()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9339720bfe34> in <module>()
# ----> 1 all_['personal']['political']
#
# TypeError: list indices must be integers or slices, not str

# %%
popular_subs = dict()
for subs in new['reposts']:
    for sub in subs:
        if sub in popular_subs:
            popular_subs[sub] += 1
        else:
            popular_subs[sub] = 1
sorted_x = sorted(popular_subs.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [(-23433159, 2873),
#  (-29559271, 2143),
#  (-29246653, 1873),
#  (-962291, 1853),
#  (-26307864, 1774),
#  (-58737741, 1594),
#  (-24390680, 1490),
#  (-10639516, 1469),
#  (-9828339, 1311),
#  (-41232698, 1005),
#  (-19138535, 977),
#  (-31976785, 968),
#  (-28477986, 927),
#  (-30022666, 913),
#  (-24098496, 745),
#  (-38121615, 704),
#  (-28950133, 702),
#  (-25582009, 694),
#  (-31483069, 671),
#  (-26776447, 665),
#  (-97336576, 642),
#  (-57846937, 634),
#  (-11614, 630),
#  (-460389, 630),
#  (-74082617, 627),
#  (-38233726, 623),
#  (-67580761, 616),
#  (-28556858, 613),
#  (-40443638, 590),
#  (-12382740, 589),
#  (-29689780, 583),
#  (-32645804, 576),
#  (-65960786, 576),
#  (-29599237, 562),
#  (-51214420, 519),
#  (-25346844, 515),
#  (-23213239, 501),
#  (-67359347, 498),
#  (-53474, 494),
#  (-60114472, 488),
#  (-53638725, 472),
#  (-64644733, 468),
#  (-6136139, 465),
#  (-59620308, 457),
#  (-22798006, 452),
#  (-67972801, 445),
#  (-23728250, 442),
# ...

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'TeamPutin.json'), 'w', encoding='utf8') as f:
    json.dump(all_, f, ensure_ascii=True)

# %%
for elem in all_['music']:
    elem = str(elem)
    if elem.strip() != '':
        all_['is_music'].append(1)
    else:
        all_['is_music'].append(0)

# %%
tmp = ['activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'military', 'career', 'nickname', 'relatives']
is_tmp = ['is_' + elem for elem in tmp]
for i, t in enumerate(tmp):
    all_[is_tmp[i]] = []
    for elem in all_[tmp[i]]:
        if elem != '':
            all_[is_tmp[i]].append(1)
        else:
            all_[is_tmp[i]].append(0)

# %%
numbs = []
for i, elem in enumerate(all_['military']):
    if elem == []:
        numbs.append(i)

# %%
for numb in numbs:
    all_['military'][numb] = ''

# %%
new['military'][24479]
# Out:
# [{'country_id': 1,
#   'unit': 'Северная Военно-Космическая Академия, Новая Земля',
#   'unit_id': 251147}]

# %%
numbs = []
for i, elem in enumerate(new['military']):
    if elem != '':
        numbs.append(i)

# %%
len(numbs)
# Out:
# 876

# %%
dct = dict()
for numb in numbs:
    for elem in new['military'][numb]:
        tmp = elem['unit']
        if tmp in dct:
            dct[tmp] += 1
        else:
            dct[tmp] = 1

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'military_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(all_['military'], f, ensure_ascii=True)

# %%
sorted_x = sorted(dct.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('ВДВ', 6),
#  ('ALEN I UGANDA', 5),
#  ('не служил', 4),
#  ('введите войсковую часть', 3),
#  ('военная тайна', 3),
#  ('50661 РУЦ', 2),
#  ("29982 г. Фокино ''Космические войска''", 2),
#  ('Красная Армия', 2),
#  ('Не служил! Неберут меня...', 2),
#  ('69647', 2),
#  ('357 полк ВДВ Витебская дивизия', 2),
#  ('43154 (Уфа)', 2),
#  ('55407 Нижний Новгород  отдельный           412 батальён  РЭб', 2),
#  ('секретная', 2),
#  ('Военная кафедра КГТУ (Кострома)', 2),
#  ('2333 Учебка в г.АНАПА Морские части пограничных войск РФ', 2),
#  ('73612', 2),
#  ('65416', 2),
#  ('не служил, и сильно меня туда не тянет', 2),
#  ('32087', 2),
#  ('Северная Военно-Космическая Академия, Новая Земля', 1),
#  ('03264 118 УМСП Черноречье', 1),
#  ('ВЧ 24/32  СЕВЕРНЫЙ КАВКАЗ  ПОГРАНИЧНЫЕ ВОЙСКА', 1),
#  ('ВУМОРФ', 1),
#  ('Владимир', 1),
#  ('Zivilschutzorganisation', 1),
#  ('Üem.Gtm Elektronik', 1),
#  ('Костромская военная академия РХБ защиты имени маршала С.К.Тимоше', 1),
# ...

# %%
numbs = []
for i, elem in enumerate(all_['career']):
    if elem == []:
        numbs.append(i)

# %%
for numb in numbs:
    all_['career'][numb] = ''

# %%
new = pd.DataFrame(all_)

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'career_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(all_['career'], f, ensure_ascii=True)

# %%
new['career'][0][0]
# Out:
# {'city_id': 2, 'company': 'Эриском', 'country_id': 1}

# %%
numbs = []
for i, elem in enumerate(new['career']):
    if elem != '':
        numbs.append(i)

# %%
dct = dict()
for numb in numbs:
    for elem in new['career'][numb]:
        if 'company' in elem:
            tmp = elem['company']
            if tmp in dct:
                dct[tmp] += 1
            else:
                dct[tmp] = 1

# %%
token = '099d9696099d9696099d96967a09ffdc410099d099d96965357a63d615a97ea025c229e'

# %%
er = list(dct.keys())
for i, elem in enumerate(er):
    er[i] = str(elem)

# %%
req = urllib.request.Request('https://api.vk.com/method/database.getCountriesById?country_ids={}&access_token={}&v=5.74'.format(','.join(er), token))
response = urllib.request.urlopen(req)
result = response.read().decode('utf-8')
result = json.loads(result)
result
# Out:
# {'response': [{'id': 1, 'title': 'Россия'},
#   {'id': 4, 'title': 'Казахстан'},
#   {'id': 191, 'title': 'Таиланд'},
#   {'id': 9, 'title': 'США'},
#   {'id': 2, 'title': 'Украина'},
#   {'id': 36, 'title': 'Бельгия'},
#   {'id': 185, 'title': 'Словения'},
#   {'id': 49, 'title': 'Великобритания'},
#   {'id': 18, 'title': 'Узбекистан'},
#   {'id': 65, 'title': 'Германия'},
#   {'id': 19, 'title': 'Австралия'},
#   {'id': 3, 'title': 'Беларусь'},
#   {'id': 15, 'title': 'Молдова'},
#   {'id': 215, 'title': 'Чехия'},
#   {'id': 183, 'title': 'Сирия'},
#   {'id': 153, 'title': 'Палау'},
#   {'id': 81, 'title': 'Индонезия'},
#   {'id': 14, 'title': 'Эстония'},
#   {'id': 26, 'title': 'Андорра'},
#   {'id': 88, 'title': 'Италия'},
#   {'id': 7, 'title': 'Грузия'},
#   {'id': 17, 'title': 'Туркменистан'},
#   {'id': 8, 'title': 'Израиль'},
#   {'id': 97, 'title': 'Китай'},
#   {'id': 12, 'title': 'Латвия'},
#   {'id': 79, 'title': 'Зимбабве'},
#   {'id': 200, 'title': 'Турция'},
# ...

# %%
dct_ = dict()
for elem in result['response']:
    dct_[elem['id']] = elem['title']

# %%
dct_
# Out:
# {1: 'Россия',
#  2: 'Украина',
#  3: 'Беларусь',
#  4: 'Казахстан',
#  5: 'Азербайджан',
#  6: 'Армения',
#  7: 'Грузия',
#  8: 'Израиль',
#  9: 'США',
#  10: 'Канада',
#  11: 'Кыргызстан',
#  12: 'Латвия',
#  13: 'Литва',
#  14: 'Эстония',
#  15: 'Молдова',
#  17: 'Туркменистан',
#  18: 'Узбекистан',
#  19: 'Австралия',
#  26: 'Андорра',
#  28: 'Аргентина',
#  30: 'Афганистан',
#  32: 'Бангладеш',
#  36: 'Бельгия',
#  39: 'Болгария',
#  43: 'Бразилия',
#  49: 'Великобритания',
#  61: 'Гваделупа',
#  65: 'Германия',
#  71: 'Греция',
#  73: 'Дания',
#  76: 'Египет',
#  79: 'Зимбабве',
#  80: 'Индия',
#  81: 'Индонезия',
#  87: 'Испания',
#  88: 'Италия',
#  97: 'Китай',
#  98: 'Колумбия',
#  104: 'Куба',
#  145: 'Объединенные Арабские Эмираты',
#  153: 'Палау',
#  160: 'Польша',
#  165: 'Румыния',
#  181: 'Сербия',
#  183: 'Сирия',
#  184: 'Словакия',
#  185: 'Словения',
#  191: 'Таиланд',
#  200: 'Турция',
#  201: 'Уганда',
#  209: 'Франция',
#  215: 'Чехия',
#  217: 'Швейцария',
# ...

# %%
sorted_x = sorted(dct.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('ИП', 4),
#  ('ООО Русфинанс Банк', 4),
#  ('ООО "Термоантикор" ОАО "КПД"', 3),
#  ('Кремль', 3),
#  ('ОАО НПО "Наука"', 3),
#  ('Unidance', 3),
#  ('Предприниматель', 3),
#  ('КИБР– Комитет Информационной Безопасности России (Служба безопасности киберпространства, Служба информационной контрразведки, Ситуационный Центр анализа и прогноза, Бюро информационного спецназа).',
#   2),
#  ('Молодежный парламент при Думе г.о. Тольятти', 2),
#  ('YouTube', 2),
#  ('VELOBORD', 2),
#  ('Правительство Российской Федерации', 2),
#  ('Москва', 2),
#  ('ГБУЗ СО "ТГКП №3" АПК4 ДШО', 2),
#  ('Орловское региональное отделение Партии "ЕДИНАЯ РОССИЯ"', 2),
#  ('РЖД', 2),
#  ('Планета Земля', 2),
#  ('МАИ', 2),
#  ('пенсионер', 2),
#  ('ТГ "Абсолют"', 2),
#  ('ОАО ПК "Балтика"', 2),
#  ('САФУ', 2),
#  ('ОАО "Трубодеталь"', 2),
#  ('Орифлэйм', 2),
#  ('нет', 2),
#  ('магазин', 2),
#  ('Сбербанк', 2),
#  ('-', 2),
#  ('ЗАО "Транс-Строй"', 2),
#  ('ОАО "Брянсксантехника"', 2),
#  ('Россия', 2),
# ...

# %%
sorted_x = sorted(dct.items(), key=operator.itemgetter(1))
for elem in sorted_x[::-1]:
    print(dct_[elem[0]], ':', elem[1])
# Out:
# Россия : 3356
# Украина : 72
# США : 27
# Беларусь : 23
# Казахстан : 19
# Молдова : 8
# Германия : 7
# Великобритания : 7
# Италия : 5
# Сербия : 4
# Узбекистан : 4
# Бангладеш : 3
# Уганда : 3
# Турция : 3
# Израиль : 3
# Грузия : 3
# Бразилия : 2
# Кыргызстан : 2
# Индия : 2
# Румыния : 2
# Болгария : 2
# Испания : 2
# Китай : 2
# Эстония : 2
# Индонезия : 2
# Австралия : 2
# Словения : 2
# Швейцария : 1
# Азербайджан : 1
# Ямайка : 1
# Аргентина : 1
# Объединенные Арабские Эмираты : 1
# Афганистан : 1
# Дания : 1
# Греция : 1
# Канада : 1
# Куба : 1
# Колумбия : 1
# Франция : 1
# Южно-Африканская Республика : 1
# Польша : 1
# Словакия : 1
# Литва : 1
# Япония : 1
# Армения : 1
# Египет : 1
# Шри-Ланка : 1
# Гваделупа : 1
# Швеция : 1
# Зимбабве : 1
# Латвия : 1
# Туркменистан : 1
# Андорра : 1
# Палау : 1
# Сирия : 1
# Чехия : 1
# Бельгия : 1
# Таиланд : 1

# %%
for elm in ['p', 'o', 'l', 'i', 't', 'c', 'a', ',', ' ', 'n', 'g', 's', 'r', 'e', 'd', '_', 'b', 'y', 'm', 'f', 'k', 'h']:
    all_.pop(elm)

# %%
arr = 'political, langs, religion, inspired_by, people_main, life_main, smoking, alcohol'.split(', ')
for elem in arr:
    all_[elem] = []

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol'])

# %%
for elem in all_['personal']:
    for a in arr:
        if a in elem:
            all_[a].append(elem[a])
        else:
            all_[a].append('')

# %%
new = pd.DataFrame(all_)

# %%
langs = dict()
for elem in all_['langs']:
    for lang in elem:
        if lang in langs:
            langs[lang] += 1
        else:
            langs[lang] = 1

# %%
sorted_x = sorted(langs.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('Русский', 1277),
#  ('English', 1097),
#  ('Deutsch', 223),
#  ('Українська', 151),
#  ('Français', 144),
#  ('Español', 74),
#  ('Italiano', 51),
#  ('Татарча', 48),
#  ('العربية', 37),
#  ('日本語', 33),
#  ('Lingua Latina', 32),
#  ('汉语', 32),
#  ('Беларуская', 29),
#  ('Türkçe', 28),
#  ('Հայերեն', 26),
#  ('Српски', 24),
#  ('Čeština', 22),
#  ('Башҡортса', 22),
#  ('Polski', 22),
#  ('Қазақша', 21),
#  ('עברית', 18),
#  ('Azərbaycan dili', 13),
#  ('O‘zbek', 12),
#  ('Ελληνικά', 12),
#  ('Suomi', 12),
#  ('Български', 11),
#  ('Нохчийн мотт', 11),
#  ('Тоҷикӣ', 10),
#  ('Slovenčina', 9),
#  ('한국어', 9),
#  ('Саха тыла', 8),
#  ('Português', 8),
#  ('Беларуская (тарашкевiца)', 8),
#  ('МагӀарул мацӀ', 8),
#  ('فارسی', 8),
#  ('Романи', 8),
#  ('Буряад', 8),
#  ('Словѣ́ньскъ', 8),
#  ('ქართული', 8),
#  ('Română', 8),
#  ('Svenska', 8),
#  ('Русский жестовый', 8),
#  ('中文 (繁體)', 7),
#  ('Чăвашла', 7),
#  ('Português brasileiro', 6),
#  ('Norsk', 6),
#  ('Latviešu', 6),
# ...

# %%
religs = dict()
for elem in all_['religion']:
    elem = elem.lower().strip()
    if elem in religs:
        religs[elem] += 1
    else:
        religs[elem] = 1

# %%
pd.value_counts(new['inspired_by'])
# Out:
#                                                                           22985
# Музыка                                                                       47
# музыка                                                                       25
# Любовь                                                                       22
# Жизнь                                                                        19
# Семья                                                                        16
# жизнь                                                                        15
# природа                                                                      13
# Природа                                                                      11
# Друзья                                                                        9
# любовь                                                                        9
# Книги                                                                         9
# ...

# %%
popular_words = dict()
for about in new['inspired_by']:
    words = about.lower().split(',')
    for word in words:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 23004),
#  ('музыка', 166),
#  ('природа', 73),
#  ('жизнь', 68),
#  ('любовь', 62),
#  ('книги', 56),
#  ('семья', 46),
#  ('люди', 36),
#  ('друзья', 33),
#  ('спорт', 30),
#  ('дети', 30),
#  ('путешествия', 22),
#  ('искусство', 17),
#  ('работа', 14),
#  ('кино', 13),
#  ('россия', 13),
#  ('море', 12),
#  ('фильмы', 11),
#  ('футбол', 10),
#  ('танцы', 10),
#  ('интернет', 10),
#  ('живопись', 9),
#  ('девушки', 9),
#  ('моя семья', 9),
#  ('общение', 8),
#  ('красота', 8),
#  ('music', 8),
#  ('мама', 8),
#  ('солнце', 8),
#  ('жена', 8),
#  ('стихи', 8),
#  ('мир', 8),
#  ('отдых', 7),
#  ('бог', 7),
#  ('вселенная', 7),
#  ('деньги', 7),
#  ('творчество', 7),
#  ('театр', 7),
#  ('сама жизнь', 6),
#  ('политика', 6),
#  ('интересные люди', 6),
#  ('любимые люди', 6),
#  ('родители', 6),
#  ('женщины', 6),
#  ('сын', 6),
#  ('путин', 6),
#  ('фотография', 6),
#  ('лес', 6),
#  ('космос', 6),
#  ('история', 5),
#  ('дождь', 5),
#  ('секс', 5),
#  ('позитив', 5),
# ...

# %%
pd.value_counts(new['alcohol'])
# Out:
#      21676
# 1      800
# 2      704
# 4      687
# 3      485
# 5      145
# Name: alcohol, dtype: int64

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives'])

# %%
numbs = []
for i, elem in enumerate(all_['relatives']):
    if elem == []:
        numbs.append(i)

# %%
for numb in numbs:
    all_['relatives'][numb] = ''

# %%
new = pd.DataFrame(all_)

# %%
numbs = []
for i, elem in enumerate(all_['relatives']):
    if elem != '':
        numbs.append(i)

# %%
len(numbs)
# Out:
# 3120

# %%
occ_ids = dict()
names = dict()
types = dict()
for elem in new['occupation']:
    if 'id' in elem:
        tmp = elem['id']
        if tmp in occ_ids:
            occ_ids[tmp] += 1
        else:
            occ_ids[tmp] = 1
    if 'name' in elem:
        tmp = elem['name']
        if tmp in names:
            names[tmp] += 1
        else:
            names[tmp] = 1
    if 'type' in elem:
        tmp = elem['type']
        if tmp in types:
            types[tmp] += 1
        else:
            types[tmp] = 1

# %%
new['occupation'][24469]
# Out:
# {'id': 31037, 'name': 'МПИ ФСБ РФ (бывш. МВИ ФПС РФ)', 'type': 'university'}

# %%
sorted_x = sorted(occ_ids.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [(2, 152),
#  (79145826, 107),
#  (1, 73),
#  (107071607, 52),
#  (477, 50),
#  (92, 48),
#  (3415, 46),
#  (918, 39),
#  (653, 35),
#  (236, 35),
#  (101759, 34),
#  (56, 31),
#  (795, 28),
#  (863, 28),
#  (364, 27),
#  (213, 27),
#  (527, 26),
#  (1047, 26),
#  (452, 26),
#  (602, 25),
#  (338, 25),
#  (131, 25),
#  (247, 25),
#  (56514, 24),
#  (574, 24),
#  (6627, 24),
#  (856, 24),
#  (851, 24),
#  (914, 23),
#  (716, 23),
#  (473, 23),
#  (503, 23),
#  (865, 23),
#  (34, 23),
#  (6446, 22),
#  (909, 22),
#  (219, 22),
#  (613, 21),
#  (387, 21),
#  (669, 21),
#  (326, 21),
#  (348, 20),
#  (920, 20),
#  (915, 20),
#  (250, 20),
#  (853, 20),
#  (883, 20),
#  (257, 20),
#  (526, 19),
#  (155639180, 19),
#  (212, 19),
#  (380, 19),
#  (328, 19),
#  (729, 19),
#  (405, 18),
#  (695, 18),
#  (265, 18),
#  (841, 18),
#  (81, 18),
#  (670, 17),
#  (862, 17),
#  (263, 17),
#  (782, 17),
#  (881, 17),
#  (228, 17),
#  (730, 17),
#  (133164333, 16),
#  (643, 16),
#  (801, 16),
# ...

# %%
sorted_x = sorted(names.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('МГУ', 152),
#  ('Эта страница официально подтверждена 🌟', 108),
#  ('СПбГУ', 73),
#  ('Школа №1', 72),
#  ('🔔 Эта страница официально подтверждена', 53),
#  ('УрФУ им. первого Президента России Б. Н. Ельцина', 50),
#  ('РАНХиГС при Президенте РФ (АНХ при Правительстве РФ, РАГС при Президенте РФ)',
#   48),
#  ('ЮФУ (бывш. РГУ)', 46),
#  ('ЮУрГУ (НИУ)', 39),
#  ('ННГУ им. Лобачевского', 35),
#  ('Таврическая академия КФУ им. В. И. Вернадского (бывш. ТНУ)', 35),
#  ('МГИМО МИД России', 35),
#  ('СПбПУ Петра Великого (Политех)', 31),
#  ('ТюмГУ', 29),
#  ('СГЮА (бывш. СГАП, СГЮИ им. Курского)', 28),
#  ('САФУ им. М. В. Ломоносова', 27),
#  ('МГЮА (Университет им. О. Е. Кутафина)', 27),
#  ('Школа №4', 26),
#  ('Школа №2', 26),
#  ('КФУ (бывш. КГУ им. Ульянова-Ленина)', 26),
#  ('КГУ', 26),
#  ('ВГУ', 26),
#  ('ОГУ', 25),
#  ('ЮЗГУ (КурскГТУ)', 25),
#  ('РУДН', 25),
#  ('ГУУ', 25),
#  ('МГСУ НИУ (МГСУ-МИСИ)', 25),
#  ('ТГУ им. Державина', 24),
#  ('КубГУ', 24),
# ...

# %%
sorted_x = sorted(types.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('university', 6505), ('work', 4831), ('school', 1205)]

# %%
np.mean(new['followers_count'])
# Out:
# 222.05519043148141

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives'])

# %%
last_seens = dict()
for elem in new['last_seen']:
    if 'platform' in elem:
        tmp = elem['platform']
        if tmp in last_seens:
            last_seens[tmp] += 1
        else:
            last_seens[tmp] = 1

# %%
sorted_x = sorted(last_seens.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [(4, 9819), (2, 6002), (7, 5308), (1, 2946), (5, 199), (3, 185), (6, 16)]

# %%
popular_words = dict()
for about in new['status']:
    words = about.lower().split()
    for word in words:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 3594),
#  ('не', 2396),
#  ('и', 2174),
#  ('в', 1828),
#  ('я', 1169),
#  ('что', 831),
#  ('на', 781),
#  ('с', 696),
#  ('это', 559),
#  ('а', 540),
#  ('ты', 530),
#  ('все', 472),
#  ('как', 428),
#  ('у', 411),
#  ('за', 408),
#  ('жизнь', 383),
#  ('если', 360),
#  ('меня', 352),
#  ('кто', 336),
#  ('то', 330),
#  ('мы', 313),
#  ('но', 312),
#  ('по', 303),
#  ('только', 292),
#  ('когда', 288),
#  ('мне', 285),
#  ('есть', 282),
#  ('быть', 279),
#  ('к', 279),
#  ('тебя', 278),
#  ('всё', 275),
#  ('жизни', 264),
#  ('будет', 246),
#  ('для', 244),
#  ('так', 233),
#  ('от', 232),
#  ('вы', 221),
#  ('нет', 212),
#  ('люблю', 209),
#  ('всегда', 202),
#  ('о', 190),
#  ('чтобы', 182),
#  ('счастье', 171),
#  ('чем', 161),
#  ('никогда', 161),
#  ('из', 159),
#  ('вас', 157),
#  ('мир', 156),
#  ('the', 154),
#  ('себя', 152),
#  ('нас', 145),
#  ('всем', 144),
#  ('надо', 142),
#  ('он', 138),
#  ('тебе', 136),
#  ('жить', 134),
#  ('лучше', 131),
#  ('мой', 130),
# ...

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives'])

# %%
popular_words = dict()
for about in new['site']:
    words = about.lower().split('/')
    for word in words:
        word = word.strip()
        word = word.strip('.,/><?!@#$%^&*();\"\'—–_-+[]=0123456789')
        if word in popular_words:
            popular_words[word] += 1
        else:
            popular_words[word] = 1
sorted_x = sorted(popular_words.items(), key=operator.itemgetter(1))
sorted_x[::-1]
# Out:
# [('', 24137),
#  ('http:', 1556),
#  ('https:', 1129),
#  ('vk.com', 942),
#  ('app', 355),
#  ('ask.fm', 250),
#  ('id', 242),
#  ('vkontakte.ru', 222),
#  ('www.instagram.com', 214),
#  ('sprashivai.ru', 124),
#  ('club', 119),
#  ('www.youtube.com', 100),
#  ('нет', 97),
#  ('channel', 72),
#  ('www.facebook.com', 53),
#  ('instagram.com', 53),
#  ('twitter.com', 53),
#  ('нету', 43),
#  ('steamcommunity.com', 35),
#  ('avtor', 35),
#  ('www.stihi.ru', 35),
#  ('user', 33),
#  ('users', 21),
#  ('askfm.im', 19),
#  ('www.drive2.ru', 18),
#  ('t.me', 18),
#  ('promodj.com', 15),
#  ('ok.ru', 15),
#  ('public', 15),
#  ('profile', 14),
#  ('c', 13),
#  ('sparshivai.ru', 13),
#  ('ru', 13),
#  ('www', 11),
#  ('goo.gl', 11),
#  ('ref', 10),
#  ('вк', 9),
#  ('sprashlvai.ru', 9),
#  ('kremlin.ru', 9),
#  ('instgram.ru', 9),
#  ('www.odnoklassniki.ru', 9),
#  ('www.kremlin.ru', 8),
#  ('edit?act=contacts', 7),
#  ('в разработке', 7),
#  (' https:', 7),
#  ('vk.cc', 7),
# ...

# %%
pd.value_counts(new['contacts'])
# Out:
# 0    20785
# 1     3712
# Name: contacts, dtype: int64

# %%
new['domain']
# Out:
# 0                     bluesman
# 1                       id1948
# 2        maksimillian_selyutin
# 3                        mrfed
# 4                        bu14h
# 5                     lutaenko
# 6                      footgen
# 7                      id18452
# 8                  katrinsev07
# 9                    a.lagunov
# 10                     id33185
# 11              nastya_ecology
# 12                     dob_bob
# 13                      chazov
# 14                samokhodkina
# 15                       vigos
# 16                     id67143
# 17                     id67914
# 18                     id75932
# 19                     id79104
# 20                     id91672
# 21                     wangwen
# 22                 pogrebskikh
# 23                    id102119
# 24                   triglav86
# 25                monononono35
# 26                    id111701
# 27                    id119160
# 28                    id120872
# 29                    id125123
# ...

# %%
all_['is_domain'] = []
for elem in new['domain']:
    if elem.startswith('id'):
        all_['is_domain'].append(0)
    else:
        all_['is_domain'].append(1)
#     if elem.start

# %%
new = pd.DataFrame(all_)

# %%
pd.value_counts(new['is_domain'])
# Out:
# 0    13822
# 1    10675
# Name: is_domain, dtype: int64

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain'])

# %%
days = dict()
months = dict()
years = dict()
for elem in new['bdate']:
    if elem.strip() != '':
        tmp = elem.split('.')
        if len(tmp) == 3:
            day, month, year = tmp[0], tmp[1], tmp[2]
            if day in days:
                days[day] += 1
            else:
                days[day] = 1
            if month in months:
                months[month] += 1
            else:
                months[month] = 1
            if year in years:
                years[year] += 1
            else:
                years[year] = 1
        else:
            day, month = tmp[0], tmp[1]
            if day in days:
                days[day] += 1
            else:
                days[day] = 1
            if month in months:
                months[month] += 1
            else:
                months[month] = 1

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain'])

# %%
pd.value_counts(new['verified'])
# Out:
# 0    24493
# 1        4
# Name: verified, dtype: int64

# %%
type(years)
# Out:
# dict

# %%
for j, elem in enumerate(all_['country']):
    if type(elem) != str:
        print(elem)

# %%
for j, elem in enumerate(all_['city']):
    if elem != '':
        all_['city'][j] = elem['title']

# %%
tmp = [x for x in list(pd.unique(new['city'])) if x]
tmp
# Out:
# ['Санкт-Петербург',
#  'Барнаул',
#  'Москва',
#  'Казань',
#  'Нарьян-Мар',
#  'Тюмень',
#  'Уфа',
#  'Саров',
#  'Симферополь',
#  'Пермь',
#  'Ялта',
#  'Клин',
#  'Питер',
#  'Всеволожск',
#  'Калининград',
#  'Омск',
#  'Тосно',
#  'Томск',
#  'Череповец',
#  'Краснодар',
#  'New York City',
#  'Петрозаводск',
#  'Камчатка',
#  'Ухта',
#  'Домодедово',
#  'San Francisco',
#  'Алматы',
#  'Георгиевск',
#  'Салехард',
#  'Щелково-4',
#  'Северодвинск',
#  'Брянск',
#  'Гатчина',
#  'Сыктывкар',
#  'Севастополь',
#  'Югорск',
#  'Петропавловск-Камчатский',
#  'Абакан',
#  'Сосновый Бор',
#  'Лесной',
#  'Саки',
#  'Воронеж',
#  'Екатеринбург',
#  'Чебоксары',
#  'Долгопрудный',
#  'Красноярск',
#  'Vantaa',
#  'Мурманск',
#  'Нижний Новгород',
#  'Челябинск',
#  'Минеральные Воды',
#  'Ростов-на-Дону',
#  'Улан-Удэ',
#  'Владивосток',
#  'Коммунар',
#  'Сургут',
#  'Николаевка',
#  'Самара',
#  'München',
#  'Сочи',
#  'Ярославль',
#  'Киров',
#  'Железногорск',
#  'Palma',
# ...

# %%
cities = dict()
main = 'https://ru.wikipedia.org/wiki/'
for elem in tmp:
    url = main + quote(elem)
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.9 (Windows NT 6.1; Win64; x64)'})
    try:
        response = urllib.request.urlopen(req)
    except:
        print(elem)
        continue
    html = response.read().decode('utf-8')
    a = re.findall('data-lat=\"(.*?)\" data-lon=\"(.*?)\"', html)
    if a != []:
        cities[elem] = a[0]
    else:
        print(elem)
# Out:
# Клин
# Питер
# Домодедово
# Щелково-4
# Сосновый Бор
# Лесной
# Саки
# Vantaa
# Коммунар
# Николаевка
# München
# Киров
# Железногорск
# Palma
# Барыш
# Судак
# Ljubljana
# Tallahassee
# Antibes
# Vechta
# Frankfurt am Main
# Чайковский
# Карасук
# Власиха
# Назарово
# Sankt Pölten
# Орёл
# Радужный
# Октябрьский
# Чехов
# Верхнее Алябьево
# Ko Samui
# Энгельс
# Владимир
# Ожерелье
# Hyvinkää
# Maribor
# Brescia
# Boston
# Энергетик
# Мирный
# Курган
# Белогорск
# Останино
# Wokingham
# Высокий
# Chicago
# Петропавловка
# Andorra la Vella
# Новофедоровка
# Суворов
# Каргат
# Or Akiva
# Лермонтов
# Вичуга Старая
# Шелехов
# Королёв
# Петушки
# Cannes
# Bangkok
# Фабричная
# Красное
# Гамово
# Жуковский
# Сланцы
# Tijuana
# Kingston
# Agadir
# Буинск
# Canberra
# Починки
# Чернушка
# Истра
# Marbella
# Пересвет
# Frederick
# Красноборск
# Пушкин
# Яминский
# Лениногорск
# Плесецк
# Борское
# Армавир
# Колывань
# Voghera
# Bolzano
# Latakia
# Марьино
# Александров
# Гай
# Софрино-1
# ...

# %%
cits = []
with open('cities.txt', 'r', encoding='utf-8') as f:
    for line in f.readlines():
        cits.append(line.strip())

# %%
main = 'https://nominatim.openstreetmap.org/search.php?q='
for elem in cits:
    url = main + quote(elem)
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.9 (Windows NT 6.1; Win64; x64)'})
    response = urllib.request.urlopen(req)
    html = response.read().decode('utf-8')
    a = re.findall('\"lon\": \"(.*?)\",.*?\"lat\": \"(.*?)\"', html, re.DOTALL)
    if a != []:
        cities[elem] = a[0]
    else:
        print(elem)
# Out:
# Сочилово
# Свердловск / Должанск
# Хрустальный / Красный Луч
# Давыдово (Давыдовский с/о)
# Шахтерск
# Адлер (микрорайон)
# 104 км автотрассы Брянск-Орел
# Поныри 1-е
# Сегян-Кюель
# Черемное с/з
# А/Д Казань-Арск перекресток к нп Каменка
# Hatzfeld (Eder), Stadt

# %%
with open('geocords.txt', 'r', encoding='utf-8') as f:
    for line in f.readlines():
        er = line.split('\t')
        cities[er[0]] = tuple(er[1].strip().split(','))

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'geo_of_cities_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(cities, f, ensure_ascii=True)

# %%
cities
# Out:
# {'Санкт-Петербург': ('59.95', '30.31667'),
#  'Барнаул': ('53.347361', '83.77833'),
#  'Москва': ('55.75583', '37.61778'),
#  'Казань': ('55.79083', '49.11444'),
#  'Нарьян-Мар': ('67.63778', '53.00667'),
#  'Тюмень': ('57.15', '65.53333'),
#  'Уфа': ('54.73333', '55.96667'),
#  'Саров': ('54.93333', '43.31667'),
#  'Симферополь': ('44.94806', '34.10417'),
#  'Пермь': ('58.01389', '56.24889'),
#  'Ялта': ('44.49944', '34.15528'),
#  'Всеволожск': ('60.01667', '30.65'),
#  'Калининград': ('54.71667', '20.5'),
#  'Омск': ('54.96667', '73.38333'),
#  'Тосно': ('59.55', '30.9'),
#  'Томск': ('56.48861', '84.95222'),
#  'Череповец': ('59.11667', '37.9'),
#  'Краснодар': ('45.03333', '38.98333'),
#  'New York City': ('40.72833', '-73.99417'),
#  'Петрозаводск': ('61.79611', '34.34917'),
#  'Камчатка': ('57', '160'),
#  'Ухта': ('63.56667', '53.7'),
#  'San Francisco': ('37.76667', '-122.43333'),
#  'Алматы': ('43.25', '76.9'),
#  'Георгиевск': ('44.15', '43.46667'),
# ...

# %%
sumup = dict()

# %%
sumup['type'] = "FeatureCollection"

# %%
sumup['features'] = []

# %%
cities[all_['city'][i]][0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-359-07b735c26102> in <module>()
# ----> 1 int(cities[all_['city'][i]][0])
#
# ValueError: invalid literal for int() with base 10: '59.95'

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain'])

# %%
for key in cities.keys():
    cities[key] = list(cities[key])

# %%
for key in cities.keys():
    cities[key][0] = float(cities[key][0])
    cities[key][1] = float(cities[key][1])

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain'])

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain'])

# %%
key = "099d9696099d9696099d96967a09ffdc410099d099d96965357a63d615a97ea025c229e" # сервисный ключ доступа

# %%
site = 'https://vk.com/putinteam' # vk-public PutinTeam

# %%
title = site.split('/')[-1]

# %%
req = urllib.request.Request('https://api.vk.com/method/groups.getMembers?group_id={}&sort={}&count={}&v=5.74&access_token={}'.format(title, 'id_asc', 1, key))
response = urllib.request.urlopen(req)
result = response.read().decode('utf-8')
result = json.loads(result)

# %%
total = result['response']['count'] # общее число людей в сообществе
total
# Out:
# 26021

# %%
n = 1000
offsets = [str(i * n) for i in range((total // n) + 1)] # заведём массив с нужным числом отсутпов

# %%
ids = []
for offset in offsets:
    req = urllib.request.Request('https://api.vk.com/method/groups.getMembers?group_id={}&sort={}&offset={}&count={}&v=5.74&access_token={}'.format(title, 'id_asc', offset, n, key))
    response = urllib.request.urlopen(req)
    result = response.read().decode('utf-8')
    result = json.loads(result)
    ids.extend(result['response']['items'])

# %%
all_.keys()
# Out:
# dict_keys(['reposts', 'subscriptions', 'friends', 'first_name', 'last_name', 'graduation', 'faculty_titles', 'faculty_ids', 'university_titles', 'university_ids', 'city', 'country', 'verified', 'sex', 'bdate', 'home_town', 'has_photo', 'photo_max_orig', 'domain', 'has_mobile', 'contacts', 'age', 'site', 'universities', 'schools', 'status', 'last_seen', 'followers_count', 'occupation', 'nickname', 'relatives', 'relation', 'personal', 'wall_comments', 'activities', 'interests', 'music', 'movies', 'tv', 'books', 'games', 'about', 'quotes', 'career', 'military', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career', 'political', 'langs', 'religion', 'inspired_by', 'people_main', 'life_main', 'smoking', 'alcohol', 'is_nickname', 'is_relatives', 'is_domain', 'ids', 'lat', 'lon'])

# %%
sumup = {"type": "FeatureCollection", "features": []}
related = []
all_['lat'] = []
all_['lon'] = []

# %%
all_['city'][0]
# Out:
# 'Санкт-Петербург'

# %%
cities['Москваа']
# Out:
# [55.75583, 37.61778]

# %%
cities['Зеленогорский '] = [86.953, 55.0011]

# %%
for i in range(len(all_["age"][17600:])):
    print(i + 17600)
    if all_['city'][i] == '':
        all_['lat'].append('')
        all_['lon'].append('')
        continue
    city = all_['city'][i] 
    lat = cities[city][1] + np.random.normal(scale=0.05)
    lon = cities[city][0] + np.random.normal(scale=0.05)
    all_['lat'].append(lat)
    all_['lon'].append(lon)
    local = dict()
    local["type"] = "Feature"
    local["geometry"] = {"type": "Point", "coordinates": [lat, lon]}
    local["properties"] = dict()
    for key in all_.keys():
        if key not in ['reposts', 'subscriptions', 'friends', 'last_seen', 'occupation', 'is_nickname', 'is_relatives', 'is_domain', 'is_activities', 'is_interests', 'is_music', 'is_movies', 'is_tv', 'is_books', 'is_games', 'is_about', 'is_quotes', 'is_military', 'is_career'] and all_[key][i] != '':
            local['properties'][key] = all_[key][i]
    local["properties"]['marker-color'] = marker_colors[city]
    local["properties"]['marker-size'] = marker_sizes[city]
    local["properties"]['marker-symbol'] = "city"
    sumup['features'].append(local)
    for friend in all_['friends'][i]:
        if friend in ids:
            if type(all_['ids'][i]) != str:
                if friend > all_['ids'][i]:
                    related.append([all_['ids'][i], friend])
# Out:
# 8219
# 8220
# 8221
# 8222
# 8223
# 8224
# 8225
# 8226
# 8227
# 8228
# 8229
# 8230
# 8231
# 8232
# 8233
# 8234
# 8235
# 8236
# 8237
# 8238
# 8239
# 8240
# 8241
# 8242
# 8243
# 8244
# 8245
# 8246
# 8247
# 8248
# 8249
# 8250
# 8251
# 8252
# 8253
# 8254
# 8255
# 8256
# 8257
# 8258
# 8259
# 8260
# 8261
# 8262
# 8263
# 8264
# 8265
# 8266
# 8267
# 8268
# 8269
# 8270
# 8271
# 8272
# 8273
# 8274
# 8275
# 8276
# 8277
# 8278
# 8279
# 8280
# 8281
# 8282
# 8283
# 8284
# 8285
# 8286
# 8287
# 8288
# 8289
# 8290
# 8291
# 8292
# 8293
# 8294
# 8295
# 8296
# 8297
# 8298
# 8299
# 8300
# 8301
# 8302
# 8303
# 8304
# 8305
# 8306
# 8307
# 8308
# 8309
# 8310
# 8311
# 8312
# 8313
# 8314
# 8315
# 8316
# 8317
# 8318
# 8319
# 8320
# 8321
# 8322
# 8323
# 8324
# 8325
# 8326
# 8327
# 8328
# 8329
# 8330
# 8331
# 8332
# 8333
# 8334
# 8335
# 8336
# 8337
# 8338
# 8339
# 8340
# 8341
# 8342
# 8343
# 8344
# 8345
# 8346
# 8347
# 8348
# 8349
# 8350
# 8351
# 8352
# 8353
# 8354
# 8355
# 8356
# 8357
# 8358
# 8359
# 8360
# ...

# %%
with open(os.path.join(r'Работы по DH\Putin_VS_Navalny', 'geojson_Putin.json'), 'w', encoding='utf8') as f:
    json.dump(sumup, f, ensure_ascii=True)

# %%
all_['ids'][:5]
# Out:
# [912, 1948, 2128, 6559, 8323]

# %%
all_['ids'].index(related[2][0])
# Out:
# 3

# %%
related[:5]
# Out:
# [[2128, 25317378],
#  [2128, 436534452],
#  [6559, 5309958],
#  [6559, 87330487],
#  [6559, 120259257]]

# %%
local = dict()
ind1 = all_['ids'].index(2128)
ind2 = all_['ids'].index(6559)
local["type"] = "Feature"
local["geometry"] = {"type": "LineString", "coordinates": [[all_['lat'][ind1], all_['lon'][ind1]], [all_['lat'][ind2], all_['lon'][ind2]]]}
local["properties"] = dict()
local['properties']['stroke'] = "#000000"
local['properties']['stroke-width'] = 1
local['properties']['stroke-opacity'] = 1
sumup['features'].append(local)

# %%
for link in related:
    local = dict()
    local["type"] = "Feature"
    local["geometry"] = {"type": "LineString", "coordinates": [link]}
    local["properties"] = dict()
    sumup['features'].append(local)

# %%
import random
r = lambda: random.randint(0,255)
print('#%02X%02X%02X' % (r(),r(),r()))
# Out:
# <function <lambda> at 0x000002479D452158>
# #D1BEC0

# %%
marker_colors = dict()
for elem in cities.keys():
    marker_colors[elem] = '#%02X%02X%02X' % (r(),r(),r())

# %%
all_.pop('lat')
all_.pop('lon')
# Out:
# [59.95952224143771,
#  '',
#  59.95921904252695,
#  53.341140959016876,
#  55.687135252944564,
#  59.972898401853776,
#  59.99889455803753,
#  55.75637553563079,
#  60.02487626398744,
#  55.846578531721185,
#  '',
#  59.96511738432977,
#  59.950810056326105]

# %%
new = pd.DataFrame(all_)

# %%
cities.pop('Зеленогорский')
# Out:
# [42.6670459, 43.9049742]

# %%
tmp = pd.value_counts(new['city'])
marker_sizes = dict()
for elem in cities:
    if tmp[elem] > 300:
        marker_sizes[elem] = 'small'
    elif tmp[elem] > 50:
        marker_sizes[elem] = 'medium'
    else:
        marker_sizes[elem] = 'large'

# %%
# Out:
# '{"type": "FeatureCollection", "features": [{"type": "Feature", "geometry": {"type": "Point", "coordinates": [30.302424174816274, 59.95952224143771]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [30.305317927137413, 59.95921904252695]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [83.73950402431491, 53.341140959016876]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [37.64774292421019, 55.687135252944564]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [30.312843763222368, 59.972898401853776]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [30.31551257583034, 59.99889455803753]}, "properties": {"sex": 2}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [37.60472986617779, 55.75637553563079]}, "properties": {"sex": 2}}, {"type": "Feature
# ...

# %%
all_['ids'] = []

# %%
for i, elem in enumerate(new['domain'][2265:]):
    print(i+2265)
    req = urllib.request.Request('https://api.vk.com/method/utils.resolveScreenName?screen_name={}&v=5.74&access_token={}'.format(elem, key))
    response = urllib.request.urlopen(req)
    result = response.read().decode('utf-8')
    result = json.loads(result)
    if 'object_id' not in result['response']:
        all_['ids'].append('')
    else:
        all_['ids'].append(result['response']['object_id'])
# Out:
# 2265
# 2266
# 2267
# 2268
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# 2276
# 2277
# 2278
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2285
# 2286
# 2287
# 2288
# 2289
# 2290
# 2291
# 2292
# 2293
# 2294
# 2295
# 2296
# 2297
# 2298
# 2299
# 2300
# 2301
# 2302
# 2303
# 2304
# 2305
# 2306
# 2307
# 2308
# 2309
# 2310
# 2311
# 2312
# 2313
# 2314
# 2315
# 2316
# 2317
# 2318
# 2319
# 2320
# 2321
# 2322
# 2323
# 2324
# 2325
# 2326
# 2327
# 2328
# 2329
# 2330
# 2331
# 2332
# 2333
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# 2347
# 2348
# 2349
# 2350
# 2351
# 2352
# 2353
# 2354
# 2355
# 2356
# 2357
# 2358
# 2359
# 2360
# 2361
# 2362
# 2363
# 2364
# 2365
# 2366
# 2367
# 2368
# 2369
# 2370
# 2371
# 2372
# 2373
# 2374
# 2375
# 2376
# 2377
# 2378
# 2379
# 2380
# 2381
# 2382
# 2383
# 2384
# 2385
# 2386
# 2387
# 2388
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2397
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# 2406
# ...

# %%
len(all_['ids'])
# Out:
# 24497
